# %% [markdown]
# <a href="https://colab.research.google.com/github/arun-arunisto/OpenCVTutorialAbel/blob/main/SeabornTutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset
fifa_data = pd.read_csv("/content/drive/MyDrive/Datascience&MachineLearning/datasets/fifa.csv")
fifa_data.head()
# Out:
#          Date   ARG  BRA   ESP   FRA  GER  ITA
# 0  1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1  1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 2  1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 3  1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 4  1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(data=fifa_data) #line charts
# Out:
# <Axes: >

# %%
spotify_data = pd.read_csv("/content/drive/MyDrive/Datascience&MachineLearning/datasets/spotify.csv")
spotify_data.head()
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
# 2  2017-01-08      13099919        NaN                       NaN      NaN
# 3  2017-01-09      14506351        NaN                       NaN      NaN
# 4  2017-01-10      14275628        NaN                       NaN      NaN
#
#    Unforgettable
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
spotify_data.tail()
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# 361      2869783.0
# 362      2743748.0
# 363      2441045.0
# 364      2622693.0
# 365      2627334.0

# %%
sns.lineplot(data=spotify_data)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(data=spotify_data)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16, 6))
sns.barplot(x=spotify_data["Date"], y=spotify_data["Despacito"])
# Out:
# <Axes: xlabel='Date', ylabel='Despacito'>

# %% [markdown]
# ## Tasks to complete
# - Heatmaps
# - Scatter plots
# - lmplot
# - swarmplot
# - histplot
# - kdeplot
# - jointplot
